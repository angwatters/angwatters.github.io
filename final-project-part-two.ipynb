# %%
import pandas as pd
import bqplot
import numpy as np
import ipywidgets
import matplotlib.pyplot as plt

# %%
ufo = pd.read_csv("ufo_sighting_data.csv",
dtype={"length_of_encounter_seconds": "string", "latitude": "string"})


ufo.head()
# Out:
#           Date_time                  city state/province country UFO_shape  \
# 0  10/10/1949 20:30            san marcos             tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb             tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)            NaN      gb    circle
# 3  10/10/1956 21:00                  edna             tx      us    circle
# 4  10/10/1960 20:00               kaneohe             hi      us     light
#
#   length_of_encounter_seconds described_duration_of_encounter  \
# 0                        2700                      45 minutes
# 1                        7200                         1-2 hrs
# 2                          20                      20 seconds
# 3                          20                        1/2 hour
# 4                         900                      15 minutes
#
#                                          description date_documented  \
# ...

# %%
ufo["latitude"] = pd.to_numeric(ufo["latitude"], errors="coerce")
ufo["length_of_encounter_seconds"] = pd.to_numeric(ufo["length_of_encounter_seconds"], errors="coerce")
ufo.dropna(axis=0,inplace=True)
pd.options.display.float_format = '{:20,.2f}'.format
ufo.describe()
# Out:
#        length_of_encounter_seconds             latitude            longitude
# count                    66,516.00            66,516.00            66,516.00
# mean                      6,573.00                38.71               -95.29
# std                     510,890.96                 5.84                18.48
# min                           0.01               -37.81              -176.66
# 25%                          30.00                34.20              -114.18
# 50%                         180.00                39.25               -89.60
# 75%                         600.00                42.34               -80.40
# max                  82,800,000.00                72.70               153.10

# %%
ufo['date_documented'] = pd.Series([
    pd.to_datetime(
        date,
        format = '%Y%m%d',
        errors='coerce'
    ) for date in ufo['date_documented']
])

# %%
ufo.columns
# Out:
# Index(['Date_time', 'city', 'state/province', 'country', 'UFO_shape',
#        'length_of_encounter_seconds', 'described_duration_of_encounter',
#        'description', 'date_documented', 'latitude', 'longitude'],
#       dtype='object')

# %%
import altair as alt

# %%
chart1 = alt.Chart.from_dict({
  "data": {"url": "ufo_sighting_data.csv"},
  "mark": "rect",
  "height":400,
  "width":300,
  "encoding": {
    "x":{"bin":{"maxbins":7},"field":"date_documented", "type":"temporal"},
    "y":{"field":"state/province","type":"ordinal"},
    "color":{"aggregate":"count", "type":"quantitative"} 
       } 
}
)

# %%
chart1
# Out:
# alt.Chart(...)

# %%
chart2 = alt.Chart.from_dict({
    "data": {"url": "ufo_sighting_data.csv"},
    "mark":"bar",
    "height":400,
    "width":300,
    "encoding":{
           "x":{"field":"length_of_encounter_seconds", "type":"quantitative", "title":"Length of Encounter"},
            "y": {"aggregate": "count", "axis": {"title": "Frequency"}}
     }    
}
    
)

# %%
chart2
# Out:
# alt.Chart(...)

# %%
myJekyllSaveDir = '/Users/angelawatters/Documents/GitHub/angwatters.github.io/assets/json/'

# %%
chart1.properties(width='container').save(myJekyllSaveDir+'rect_fp_bf.json')

# %%
chart2.properties(width='container').save(myJekyllSaveDir+'hist_fp_bf.json')

# %%
hist = alt.Chart.from_dict({
    "data": {"url": "ufo_sighting_data.csv"},
    "mark":"bar",
    "height":400,
    "width":300,
    "encoding":{
           "x":{"field":"length_of_encounter_seconds", "type":"quantitative", "title":"Length of Encounter"},
            "y": {"aggregate": "count", "axis": {"title": "Frequency"}}
     }    
}
    
)
hist
# Out:
# alt.Chart(...)

# %%
rect = alt.Chart.from_dict( {
  "data": {"url": "ufo_sighting_data.csv"},
  "mark": "rect",
  "height":400,
  "width":300,
  "encoding": {
    "x":{"bin":{"maxbins":7},"field":"date_documented", "type":"temporal"},
    "y":{"field":"state/province","type":"ordinal"},
    "color":{"aggregate":"count", "type":"quantitative"} 
       } 
}
)
rect
# Out:
# alt.Chart(...)

# %%
chart = alt.HConcatChart(hconcat=[rect, hist])
chart
# Out:
# alt.HConcatChart(...)

# %%
#chart.properties(width='container').save(myJekyllSavDir+'sidebyside.json')
chart.save(myJekyllSaveDir+'fp_sidebyside.json')

# %%
brush = alt.selection_interval(encodings=['x','y'])

# %%
rect = alt.Chart.from_dict( {
  "data": {"url": "ufo_sighting_data.csv"},
  "mark": "rect",
  "height":400,
  "width":300,
  "encoding": {
    "x":{"bin":{"maxbins":7},"field":"date_documented", "type":"temporal"},
    "y":{"field":"state/province","type":"ordinal"},
    "color":{"aggregate":"count", "type":"quantitative"} 
       } 
}
).add_selection(
brush
)
rect
# Out:
# alt.Chart(...)

# %%
hist = alt.Chart.from_dict({
    "data": {"url": "ufo_sighting_data.csv"},
    "mark":"bar",
    "height":400,
    "width":300,
    "encoding":{
           "x":{"field":"length_of_encounter_seconds", "type":"quantitative", "title":"Length of Encounter"},
            "y": {"aggregate": "count", "axis": {"title": "Frequency"}}
     }    
}
  ).transform_filter(
    brush
)
#hist

# %%
dashboard = rect | hist

# %%
dashboard
# Out:
# alt.HConcatChart(...)

# %%
dashboard.save(myJekyllSaveDir+'dashboard_ufo_from_dict.json')
