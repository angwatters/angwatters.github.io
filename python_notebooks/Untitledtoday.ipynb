# %%
import pandas as pd
import bqplot
import numpy as np
import ipywidgets
import matplotlib.pyplot as plt

# %%
ufo = pd.read_csv("ufo_sighting_data.csv",dtype={"length_of_encounter_seconds": "string", "latitude": "string"})

ufo.head()
# Out:
#           Date_time                  city state/province country UFO_shape  \
# 0  10/10/1949 20:30            san marcos             tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb             tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)            NaN      gb    circle
# 3  10/10/1956 21:00                  edna             tx      us    circle
# 4  10/10/1960 20:00               kaneohe             hi      us     light
#
#   length_of_encounter_seconds described_duration_of_encounter  \
# 0                        2700                      45 minutes
# 1                        7200                         1-2 hrs
# 2                          20                      20 seconds
# 3                          20                        1/2 hour
# 4                         900                      15 minutes
#
#                                          description date_documented  \
# 0  This event took place in early fall around 194...       4/27/2004
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...      12/16/2005
# 2  Green/Orange circular disc over Chester&#44 En...       1/21/2008
# 3  My older brother and twin sister were leaving ...       1/17/2004
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...       1/22/2004
#
#      latitude   longitude
# 0  29.8830556  -97.941111
# 1    29.38421  -98.581082
# 2        53.2   -2.916667
# 3  28.9783333  -96.645833
# 4  21.4180556 -157.803611

# %%
ufo["latitude"] = pd.to_numeric(ufo["latitude"], errors="coerce")
ufo["length_of_encounter_seconds"] = pd.to_numeric(ufo["length_of_encounter_seconds"], errors="coerce")
ufo.dropna(axis=0,inplace=True)
pd.options.display.float_format = '{:20,.2f}'.format
ufo.describe()
# Out:
#        length_of_encounter_seconds             latitude            longitude
# count                    66,516.00            66,516.00            66,516.00
# mean                      6,573.00                38.71               -95.29
# std                     510,890.96                 5.84                18.48
# min                           0.01               -37.81              -176.66
# 25%                          30.00                34.20              -114.18
# 50%                         180.00                39.25               -89.60
# 75%                         600.00                42.34               -80.40
# max                  82,800,000.00                72.70               153.10

# %%
ufo['date_documented'] = pd.Series([
    pd.to_datetime(
        date,
        format = '%Y%m%d',
        errors='coerce'
    ) for date in ufo['date_documented']
])

# %%
ufo[['date','time']] = ufo['Date_time'].str.split(expand=True)
ufo['datetime'] = (pd.to_datetime(ufo.pop('date'), format='%m/%d/%Y') +
                  pd.to_timedelta(ufo.pop('time') + ':00'))
ufo['year'] = pd.DatetimeIndex(ufo['datetime']).year
ufo.head()
# Out:
#           Date_time        city state/province country UFO_shape  \
# 0  10/10/1949 20:30  san marcos             tx      us  cylinder
# 3  10/10/1956 21:00        edna             tx      us    circle
# 4  10/10/1960 20:00     kaneohe             hi      us     light
# 5  10/10/1961 19:00     bristol             tn      us    sphere
# 7  10/10/1965 23:45     norwalk             ct      us      disk
#
#    length_of_encounter_seconds described_duration_of_encounter  \
# 0                     2,700.00                      45 minutes
# 3                        20.00                        1/2 hour
# 4                       900.00                      15 minutes
# 5                       300.00                       5 minutes
# 7                     1,200.00                      20 minutes
#
#                                          description date_documented  \
# 0  This event took place in early fall around 194...             NaT
# 3  My older brother and twin sister were leaving ...             NaT
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...             NaT
# 5  My father is now 89 my brother 52 the girl wit...             NaT
# 7  A bright orange color changing to reddish colo...             NaT
#
#               latitude            longitude            datetime  year
# 0                29.88               -97.94 1949-10-10 20:30:00  1949
# 3                28.98               -96.65 1956-10-10 21:00:00  1956
# 4                21.42              -157.80 1960-10-10 20:00:00  1960
# 5                36.59               -82.19 1961-10-10 19:00:00  1961
# 7                41.12               -73.41 1965-10-10 23:45:00  1965

# %%
ufo.columns
# Out:
# Index(['Date_time', 'city', 'state/province', 'country', 'UFO_shape',
#        'length_of_encounter_seconds', 'described_duration_of_encounter',
#        'description', 'date_documented', 'latitude', 'longitude', 'datetime',
#        'year'],
#       dtype='object')

# %%
import altair as alt

# %%
chartnew = alt.Chart.from_dict({
  "data": {"url": "https://raw.githubusercontent.com/angwatters/angwatters.github.io/main/python_notebooks/ufo_sighting_data.csv"},
  "mark": {"type": "rect", "strokeWidth": 2},
  "height":400,
  "width":300,
  "encoding": {
    "x":{"timeUnit": "year","field":"date_documented", "type":"temporal"},
    "y":{"field":"country","type":"ordinal"},
    "fill":{"aggregate":"count", "type":"quantitative"},
      
       } 
}
)

# %%
chartnew
# Out:
# alt.Chart(...)

# %%
chartfresh = alt.Chart.from_dict({
    "data": {"url": "https://raw.githubusercontent.com/angwatters/angwatters.github.io/main/python_notebooks/ufo_sighting_data.csv"},
    "mark":"bar",
    "height":400,
    "width":300,
    "encoding":{
           "x":{"field":"UFO_shape", "type":"nominal", "title":"Shape of UFO"},
            "y": {"aggregate": "count", "axis": {"title": "Frequency"}}
     }    
}
    
)

# %%
chartfresh
# Out:
# alt.Chart(...)

# %%
myJekyllSaveDir = '/Users/angelawatters/Documents/GitHub/angwatters.github.io/assets/json/'

# %%
chartnew.properties(width='container').save(myJekyllSaveDir+'heatmap_bf.json')

# %%
chartfresh.properties(width='container').save(myJekyllSaveDir+'hist_bf.json')

# %%
histfresh = alt.Chart.from_dict({
    "data": {"url": "https://raw.githubusercontent.com/angwatters/angwatters.github.io/main/python_notebooks/ufo_sighting_data.csv"},
    "mark":"bar",
    "height":400,
    "width":300,
    "encoding":{
           "x":{"field":"UFO_shape", "type":"nominal", "title":"Shape of UFO"},
            "y": {"aggregate": "count", "axis": {"title": "Frequency"}}
     }    
}
)
histfresh
# Out:
# alt.Chart(...)

# %%
rectnew = alt.Chart.from_dict({
  "data": {"url": "https://raw.githubusercontent.com/angwatters/angwatters.github.io/main/python_notebooks/ufo_sighting_data.csv"},
  "mark": "rect",
  "height":400,
  "width":300,
  "encoding": {
    "x":{"bin":{"maxbins":7},"field":"temperature_low", "type":"quantitative"},
    "y":{"field":"state","type":"ordinal"},
    "color":{"aggregate":"count", "type":"quantitative"} 
       } 
}
)
rectnew
# Out:
# alt.Chart(...)

# %%
chart = alt.HConcatChart(hconcat=[rectnew, histfresh])
chart
# Out:
# alt.HConcatChart(...)

# %%
chart.save(myJekyllSaveDir+'ufo_sidebyside.json')

# %%
brush = alt.selection_interval(encodings=['x','y'])

# %%
rectnew = alt.Chart.from_dict( {
  "data": {"url": "https://raw.githubusercontent.com/angwatters/angwatters.github.io/main/python_notebooks/ufo_sighting_data.csv"},
  "mark": {"type": "rect", "strokeWidth": 2},
  "height":400,
  "width":300,
  "encoding": {
    "x":{"timeUnit": "year","field":"date_documented", "type":"temporal"},
    "y":{"field":"country","type":"ordinal"},
    "fill":{"aggregate":"count", "type":"quantitative"},
      
       } 
}
).add_selection(
brush
)
rectnew
# Out:
# alt.Chart(...)

# %%
histfresh = alt.Chart.from_dict({
    "data": {"url": "https://raw.githubusercontent.com/angwatters/angwatters.github.io/main/python_notebooks/ufo_sighting_data.csv"},
    "mark":"bar",
    "height":400,
    "width":300,
    "encoding":{
           "x":{"field":"UFO_shape", "type":"nominal", "title":"Shape of the UFO"},
            "y": {"aggregate": "count", "axis": {"title": "Frequency"}}
     }    
}
  ).transform_filter(
    brush
)
#histfresh

# %%
dashboard = rectnew | histfresh

# %%
dashboard
# Out:
# alt.HConcatChart(...)

# %%
dashboard.save(myJekyllSaveDir+'dashboard_ufo_jekyll_from_dict.json')
